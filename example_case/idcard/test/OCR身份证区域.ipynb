# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import cv2
from example_case.idcard.card import Card
from myutils import common
dir_path = os.getcwd()+"/../images/test/20131168257.jpg"
# dir_path = os.getcwd()+"/../images/6.png"
# dir_path = os.getcwd()+"/../images/6.png"

card=Card(dir_path,isDebug=True)
img=card.getCardImg()
# img = common.fillColor(img, radio=0.1)
common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
# if img is not None:
#     common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
data_areas=card.get_data_areas(img)
result=card.ocrArea(data_areas)
print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'姓名': '', '性别': '', '民族': '', '住址': '', 'success': False}

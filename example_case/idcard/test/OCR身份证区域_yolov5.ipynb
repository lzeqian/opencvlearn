# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import cv2
from example_case.idcard.card import Card, Yolov5Card
from myutils import common
# dir_path = os.getcwd()+"/../images/test/20131168257.jpg"
# dir_path = os.getcwd()+"/../images/zm.jpg"
dir_path = os.getcwd()+"/val/00003aaaf3174f1d83a379bb88a4cf6d.png"
# dir_path = os.getcwd()+"/val/00003af195d143cd97061b6487849126.jpg"
# dir_path = os.getcwd()+"/val/00003e2383c94f5e89f145152f3ca55f.jpg"
Yolov5Card.confYolov5('D:\\code1\\yolov5-master\\yolov5-master','../yolov5/best.pt','../yolov5/bestface.pt')
card=Yolov5Card(dir_path,isDebug=True)
img,label=card.getCardImg()
# img = common.fillColor(img, radio=0.1)
common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
# if img is not None:
#     common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
data_areas=card.get_data_areas(img,label)
result=card.ocrArea(img,label)
# rotated_img=result["rotated_img"]
# if result["success"]==False:
#     card=Card(rotated_img,isDebug=True)
#     img=card.getCardImg()
#     # img = common.fillColor(img, radio=0.1)
#     common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
#     # if img is not None:
#     #     common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
#     data_areas=card.get_data_areas(img)
#     result=card.ocrArea(data_areas)
print(result)
# Out:
# YOLOv5  2023-5-30 Python-3.7.12 torch-1.13.1+cpu CPU
#
# Fusing layers...
# Model summary: 206 layers, 3089188 parameters, 0 gradients, 4.2 GFLOPs
# Adding AutoShape...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...

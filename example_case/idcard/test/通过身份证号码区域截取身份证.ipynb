# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import cv2
from example_case.idcard.card import Card
from utils import common
dir_path = os.getcwd()+"/../images/test/11111.jpg"
card1=Card(dir_path,isDebug=True)
img=card1.getCardImg()
if img is not None:
    common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

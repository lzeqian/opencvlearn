# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import cv2
from example_case.idcard.card import Card
from utils import common
from utils.common import get_all_files

dir_path = os.getcwd() + "/../images"
all_files = get_all_files(dir_path)
for i in all_files:
    card=Card(i,isDebug=False)
    print(i)
    img=card.getCardImg()
    if img is not None:
        common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
        # if img is not None:
        #     common.show(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), "身份证截取", cmap=None, debug=True)
        data_areas=card.get_data_areas(img)
        result=card.ocrArea(data_areas)
        print(result)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# D:\code\opencvlearn\example_case\idcard\test/../images\1.jpg
# {'姓名': '郁英燕', '性别': '女', '民族': '汉', '住址': '江苏省苏州市吴中区团结桥巷1号2幢506室', '出生年': '1978', '出生月': '3', '出生日': '12', '身份证号码': '32052419780312642X'}
# D:\code\opencvlearn\example_case\idcard\test/../images\2.jpg
# {'姓名': '潘双全', '性别': '男', '民族': '汉', '住址': '四川省新津县花源镇官林村5组', '出生年': '1986', '出生月': '6', '出生日': '9', '身份证号码': '0X'}
# D:\code\opencvlearn\example_case\idcard\test/../images\3.jpg
# {'姓名': '廖敏', '性别': '男', '民族': '汉', '住址': '广东省深圳市福田区福华一路6号免税商务大厦1403', '出生年': '1987', '出生月': '6', '出生日': '18', '身份证号码': '430682198706186614'}
# D:\code\opencvlearn\example_case\idcard\test/../images\4.jpg
# {'姓名': '廖敏', '性别': '男', '民族': '汉', '住址': '广东省深圳市福田区福华一路6号免税商务大厦1403', '出生年': '1987', '出生月': '6', '出生日': '18', '身份证号码': '430682198706186614'}
# D:\code\opencvlearn\example_case\idcard\test/../images\5.jpg
# {'姓名': '胡梦梦', '性别': '女', '民族': '', '住址': '浙江省永康市东城街道五金大街21-23号', '出生年': '1997', '出生月': '11', '出生日': '7', '身份证号码': '362334199711073746'}
# D:\code\opencvlearn\example_case\idcard\test/../images\6.png
# {'姓名': '黄海丹', '性别': '男', '民族': '汉', '住址': '浙江省永嘉县上塘镇永建路79号', '出生年': '1981', '出生月': '1', '出生日': '30', '身份证号码': '330324198101300011'}
# D:\code\opencvlearn\example_case\idcard\test/../images\zm.jpg
# {'姓名': '崔焕伟', '性别': '男', '民族': '', '住址': '由东苔责岛市黄岛区珠海街道办事处系新村884号', '出生月': '营华', '出生日': '4', '身份证号码': '370284199111040412'}
# D:\code\opencvlearn\example_case\idcard\test/../images\test\11111.jpg
# {'姓名': '冯花', '性别': '', '民族': '汉', '住址': '海南省东方市广坝农场胶行3NX', '出生年': '1979', '出生月': '10', '出生日': '19', '身份证号码': '460032197910193621'}
# D:\code\opencvlearn\example_case\idcard\test/../images\test\20131168257.jpg
# {'姓名': '韦小宝', '性别': '男', '民族': '汉', '住址': '北京市东城区景山前街4号紫禁城敬事房', '出生年': '1654', '出生月': '12', '出生日': '20', '身份证号码': '1124416541220243X'}
# D:\code\opencvlearn\example_case\idcard\test/../images\test\un\07090518-029ff26fac014d72a7786937e8319c78.jpg
# {'姓名': '蒋飞成', '性别': '男', '民族': '', '住址': '湖南省邵阳县五峰铺镇白田村不尤铺组1号人', '出生年': '1976', '出生月': '3', '出生日': '20', '身份证号码': '430523197603204314'}
# D:\code\opencvlearn\example_case\idcard\test/../images\test\un\downloadIdCardImage-1.jpg
# D:\code\opencvlearn\example_case\idcard\test/../images\test\un\qzl.png
# {'姓名': '权志龙', '性别': '男', '民族': '汉', '住址': '山东省五连奏城关沿河路398号6号楼3单元205店', '出生年': '1987', '出生月': '113', '出生日': '16', '身份证号码': 'X'}
# D:\code\opencvlearn\example_case\idcard\test/../images\test\un\v2-79e22af53f23f6e8be55cf913e104103_b.jpg
# D:\code\opencvlearn\example_case\idcard\test/../images\test\地址问题\d1becce8867c38f33ddaf20d344a093f.jpg
